# %%
import zipfile

# Unzip the file
with zipfile.ZipFile('signif.txt.tsv.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
import pandas as pd

df = pd.read_tsv("signif.txt.tsv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_tsv("signif.txt.tsv")
#
# AttributeError: module 'pandas' has no attribute 'read_tsv'

# %%
df.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH  DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0     1          NaN -2150    NaN  NaN   NaN     NaN                 NaN
# 1     3          NaN -2000    NaN  NaN   NaN     NaN    NaN         18.0
# 2     2          Tsu -2000    NaN  NaN   NaN     NaN    NaN          NaN
# 3  5877          Tsu -1610    NaN  NaN   NaN     NaN    NaN          NaN
# 4     8          NaN -1566    NaN  NaN   NaN     NaN                 NaN
#
#    EQ_PRIMARY  ...  TOTAL_MISSING  TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  \
# 0         7.3  ...            NaN                        NaN             NaN
# 1         7.1  ...            NaN                        NaN             NaN
# 2         NaN  ...            NaN                        NaN             NaN
# 3         NaN  ...            NaN                        NaN             NaN
# 4         NaN  ...            NaN                        NaN             NaN
#
#    TOTAL_INJURIES_DESCRIPTION  TOTAL_DAMAGE_MILLIONS_DOLLARS  \
# ...

# %%
head signif.txt.tsv
# Out:
#   Cell In[12], line 1
#     head signif.txt.tsv
#          ^
# SyntaxError: invalid syntax
